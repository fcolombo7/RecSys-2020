# %%
import os

# %%
folder = 'result_experiments_CV2/seed_1666/linear' 
filename = 'HybridCombinationSearchCV_SearchBayesianSkopt-CV.txt'

# %%
sub_folders = list(os.walk(folder))[0][1]

# %%
def get_best_config(file_content):
    complete = errors = best_found = False
    complete_metadata = {None}
    best_metadata = {}
    for l in file_content:
        if 'Search complete' in l:
            complete = True
            #get complete metadata ? Only for cross-checking
            
        elif 'New best config found' in l:
            complete = False
            best_found = True
            #get best_config metadata
            config_s = l.find('{')
            config_e = l.find('}')
            best_metadata['config'] = l[config_s+1:config_e]
            results_i = l.find('MAP') + 5
            results_e = results_i + 8
            best_metadata['results'] = float(l[results_i:results_e+1])
            
    errors = not complete or not best_found
    return best_metadata, {'complete':complete, 'best_found':best_found, 'errors':errors}

# %%
def append_sorted(container, content):
    #print(content)
    container = container.copy()
    value = content['content'][0]['results']
    index = None
    for pos, dict_ in enumerate(container):
        if dict_['content'][0]['results'] <= value:
            index = pos
            break
    #print('#',index, value)
    if index is None:
        container.append(content)
    elif index > 0:
        container.insert(index, content)
    else:
        container.insert(0, content)
    return container

# %%
all_rec = []
count=0
for sub_folder in sub_folders:
    dict_ = {}
    path = os.path.join(folder, sub_folder, filename)
    with open(path) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    dict_['rec_name'] = sub_folder
    dict_['content'] = get_best_config(content) 
    all_rec = append_sorted(all_rec, dict_)

# %%
all_rec
# Out:
# [{'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.7949204415356104, 'l1_ratio': 0.2705694962114903",
#     'results': 0.0739889},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.6094679138906033, 'l1_ratio': 0.41715098578193194",
#     'results': 0.0739867},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.8991751672246813, 'l1_ratio': 0.11874637825106651",
#     'results': 0.0736289},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.5369911284211629, 'l1_ratio': 0.45078644454282",
#     'results': 0.07362},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.6194113348305054, 'l1_ratio': 0.6156379091138154",
#     'results': 0.0735872},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.7989350513339316, 'l1_ratio': 0.4461703935735907",
#     'results': 0.0734718},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.6904008032335807, 'l1_ratio': 0.23371348584724985",
#     'results': 0.0733132},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_UserKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.627349023025726, 'l1_ratio': 0.5343474311262314",
#     'results': 0.073281},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.8129428861277737, 'l1_ratio': 0.14069122456123387",
#     'results': 0.0732549},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.8129428861277737, 'l1_ratio': 0.14069122456123387",
#     'results': 0.0732289},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_RP3betaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.7881737847053779, 'l1_ratio': 0.400772981812612",
#     'results': 0.0731503},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_UserKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.5574853559798421, 'l1_ratio': 0.5221328226891215",
#     'results': 0.0730215},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 0.411066914417302",
#     'results': 0.0729822},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_RP3betaRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.4001101186128191, 'l1_ratio': 0.9989082076640393",
#     'results': 0.0729609},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_RP3betaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 0.3362378922274294",
#     'results': 0.0729539},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.7020854096807992, 'l1_ratio': 0.20749665943340362",
#     'results': 0.0729346},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.4973334775913678, 'l1_ratio': 0.6790274919219236",
#     'results': 0.0729078},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_UserKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9033873534648698, 'l1_ratio': 0.30678626017844307",
#     'results': 0.072627},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.5238332406148302, 'l1_ratio': 0.5907932058981844",
#     'results': 0.0726098},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.45931982254221104, 'l1_ratio': 0.552400663560699",
#     'results': 0.0724929},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'Special-ItemKNNCBFRec_UserKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.7362031685050584, 'l1_ratio': 0.3394266517525301",
#     'results': 0.0724198},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.8170119826252383, 'l1_ratio': 0.33586027250410305",
#     'results': 0.0723958},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.9457062373092435, 'l1_ratio': 0.08675668683308081",
#     'results': 0.0723551},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.8162670192627814, 'l1_ratio': 0.26730373918567046",
#     'results': 0.0722529},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.7275055738435442, 'l1_ratio': 0.2694727916070659",
#     'results': 0.0721545},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.8122492419947548, 'l1_ratio': 0.1448868067763832",
#     'results': 0.0720238},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.6325200648079097, 'l1_ratio': 0.4685932097360991",
#     'results': 0.0719968},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.6383024036201149, 'l1_ratio': 0.5132363657816151",
#     'results': 0.0719338},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'Special-ItemKNNCBFRec_ItemKNNCFRecommender_UserKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.5934342246244017, 'l1_ratio': 0.38793882442583466",
#     'results': 0.0718252},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_RP3betaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.7861575718386372, 'l1_ratio': 0.34264216397962627",
#     'results': 0.0718233},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_UserKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.6642717079978444, 'l1_ratio': 0.3697767302975253",
#     'results': 0.0715318},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_UserKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.6310254748569911, 'l1_ratio': 0.42318219644561506",
#     'results': 0.0711359},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_UserKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.5388201552532741, 'l1_ratio': 0.35597718538152645",
#     'results': 0.0710556},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.43388002088179745, 'l1_ratio': 0.6820371571395787",
#     'results': 0.0709946},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.44569420382449637, 'l1_ratio': 0.6168742754254437",
#     'results': 0.0705969},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_UserKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.8127121630403612, 'l1_ratio': 0.26666033636794134",
#     'results': 0.0705199},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.3033751201293658, 'l1_ratio': 0.7822655054333012",
#     'results': 0.0704951},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_RP3betaRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.6171935935379741, 'l1_ratio': 0.4090970817953153",
#     'results': 0.0703646},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.978603744344971, 'l1_ratio': 0.3254027512340136",
#     'results': 0.0702954},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.985324214426363, 'l1_ratio': 0.9817687773282582",
#     'results': 0.0701749},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_RP3betaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9994650995751526, 'l1_ratio': 0.2154850719076557",
#     'results': 0.0701304},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9863847705892288, 'l1_ratio': 0.9381597005049093",
#     'results': 0.0700839},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9967378125954137, 'l1_ratio': 0.9991570562262023",
#     'results': 0.0700545},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNNCFRecommender_UserKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.48973465405541533, 'l1_ratio': 0.3567553681370489",
#     'results': 0.0700526},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_RP3betaRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.997965002975754, 'l1_ratio': 0.9845073880455988",
#     'results': 0.0700332},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.9764558977299022, 'l1_ratio': 0.9962086114881062",
#     'results': 0.0700313},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.9960369080995459, 'l1_ratio': 0.9991666164394999",
#     'results': 0.0700284},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender_RP3betaRecommender',
#   'content': ({'config': "'alpha': 0.9991096757033116, 'l1_ratio': 0.9969248744348811",
#     'results': 0.0700228},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender_UserKNNCFRecommender',
#   'content': ({'config': "'alpha': 0.9978504378244369, 'l1_ratio': 0.9989504324961238",
#     'results': 0.070019},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender_P3alphaRecommender',
#   'content': ({'config': "'alpha': 0.9849245373595942, 'l1_ratio': 0.9961549824044795",
#     'results': 0.0700128},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 1.0",
#     'results': 0.0700098},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 1.0",
#     'results': 0.0700098},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_ItemKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 1.0",
#     'results': 0.0700098},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 1.0",
#     'results': 0.0700098},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_RP3betaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 1.0, 'l1_ratio': 1.0",
#     'results': 0.0700098},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCBFRecommender_ItemKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.7411190540590021, 'l1_ratio': 0.30266211700854484",
#     'results': 0.0697848},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'RP3betaRecommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.20827058038030904, 'l1_ratio': 0.0706937833323922",
#     'results': 0.0639189},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'P3alphaRecommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.20827058038030904, 'l1_ratio': 0.0706937833323922",
#     'results': 0.0639173},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'UserKNNCFRecommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.33626438728146074, 'l1_ratio': 0.4983171965048039",
#     'results': 0.0638977},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCFRecommender_SLIM_BPR_Recommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.3112921487903871, 'l1_ratio': 0.12054568118105716",
#     'results': 0.0638872},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'RP3betaRecommender_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.10463256401739832, 'l1_ratio': 0.5100890005887451",
#     'results': 0.0637517},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'UserKNNCFRecommender_RP3betaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.1020039652992212, 'l1_ratio': 0.6059534331952685",
#     'results': 0.0637494},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCFRecommender_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.08202182732869136, 'l1_ratio': 0.13655438601679395",
#     'results': 0.0637383},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'UserKNNCFRecommender_P3alphaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.08202182732869136, 'l1_ratio': 0.13655438601679395",
#     'results': 0.0637056},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'ItemKNNCFRecommender_RP3betaRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.08202182732869136, 'l1_ratio': 0.13655438601679395",
#     'results': 0.0636643},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCFRecommender_UserKNNCFRecommender_S-SLIMElasticNet',
#   'content': ({'config': "'alpha': 0.08202182732869136, 'l1_ratio': 0.13655438601679395",
#     'results': 0.0636588},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNN_CBF_CF_Recommender_RP3betaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9211224203270332, 'l1_ratio': 0.3422594659470591",
#     'results': 0.0629178},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'ItemKNNCFRecommender_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9211224203270332, 'l1_ratio': 0.3422594659470591",
#     'results': 0.059442},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCFRecommender_RP3betaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9211224203270332, 'l1_ratio': 0.3422594659470591",
#     'results': 0.0591951},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'ItemKNNCFRecommender_UserKNNCFRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9211224203270332, 'l1_ratio': 0.3422594659470591",
#     'results': 0.0591265},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'RP3betaRecommender_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.99978814188919, 'l1_ratio': 0.009679662529064605",
#     'results': 0.0590001},
#    {'complete': False, 'best_found': True, 'errors': True})},
#  {'rec_name': 'UserKNNCFRecommender_RP3betaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9746049440323309, 'l1_ratio': 0.2395884577186737",
#     'results': 0.0589478},
#    {'complete': True, 'best_found': True, 'errors': False})},
#  {'rec_name': 'UserKNNCFRecommender_P3alphaRecommender_SLIM_BPR_Recommender',
#   'content': ({'config': "'alpha': 0.9211224203270332, 'l1_ratio': 0.3422594659470591",
#     'results': 0.0582481},
#    {'complete': True, 'best_found': True, 'errors': False})}]

# %%
def print_res(all_rec, at=None):
    size = len(all_rec) if at is None else at
    for i in range(size):
        rec=all_rec[i]
        if not rec['content'][1]['errors']:
            print(f"{i+1}# {rec['rec_name']} - MAP: {rec['content'][0]['results']}"+", config: {"+f"{rec['content'][0]['config']}"+"}")
        else:
            try:
                print(f"{i+1}# {rec['rec_name']} - MAP: {rec['content'][0]['results']}"+", config: {"+f"{rec['content'][0]['config']}"+"} [Warning: Something went wrong]")
            except:
                print(f"{i+1}# {rec['rec_name']} [Warning: Something went wrong]")

# %%
print_res(all_rec, at=10)
# Out:
# 1# Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_SLIM_BPR_Recommender - MAP: 0.0739889, config: {'alpha': 0.7949204415356104, 'l1_ratio': 0.2705694962114903}
# 2# Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_P3alphaRecommender - MAP: 0.0739867, config: {'alpha': 0.6094679138906033, 'l1_ratio': 0.41715098578193194}
# 3# ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_SLIM_BPR_Recommender - MAP: 0.0736289, config: {'alpha': 0.8991751672246813, 'l1_ratio': 0.11874637825106651}
# 4# Special-ItemKNNCBFRec_ItemKNN_CBF_CF_Recommender_RP3betaRecommender - MAP: 0.07362, config: {'alpha': 0.5369911284211629, 'l1_ratio': 0.45078644454282}
# 5# Special-ItemKNNCBFRec_SLIM_BPR_Recommender_S-SLIMElasticNet - MAP: 0.0735872, config: {'alpha': 0.6194113348305054, 'l1_ratio': 0.6156379091138154}
# 6# Special-ItemKNNCBFRec_P3alphaRecommender_S-SLIMElasticNet - MAP: 0.0734718, config: {'alpha': 0.7989350513339316, 'l1_ratio': 0.4461703935735907}
# 7# ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_P3alphaRecommender - MAP: 0.0733132, config: {'alpha': 0.6904008032335807, 'l1_ratio': 0.23371348584724985}
# 8# Special-ItemKNNCBFRec_UserKNNCFRecommender_P3alphaRecommender - MAP: 0.073281, config: {'alpha': 0.627349023025726, 'l1_ratio': 0.5343474311262314}
# 9# ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_UserKNNCFRecommender - MAP: 0.0732549, config: {'alpha': 0.8129428861277737, 'l1_ratio': 0.14069122456123387}
# 10# ItemKNNCBFRecommender_ItemKNN_CBF_CF_Recommender_RP3betaRecommender - MAP: 0.0732289, config: {'alpha': 0.8129428861277737, 'l1_ratio': 0.14069122456123387}
